# %%
# FOR THE TEST SET
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.family'] = 'CMU Serif'
mpl.rcParams['font.size'] = '12'

# %%
df = pd.read_csv("accuracy")
plt.plot(df['header'])
plt.xlabel("epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
df = pd.read_csv("cost")
plt.plot(df['header'])
plt.xlabel("epochs")
plt.ylabel("cost")
# Out:
# Text(0, 0.5, 'cost')
